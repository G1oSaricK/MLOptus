# %%
# !pip install findspark
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: findspark in ./.local/lib/python3.8/site-packages (2.0.1)

# %%
# !pip3 install pyspark==3.0.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyspark==3.0.3
#   Using cached pyspark-3.0.3.tar.gz (209.1 MB)
# Collecting py4j==0.10.9
#   Using cached py4j-0.10.9-py2.py3-none-any.whl (198 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.0.3-py2.py3-none-any.whl size=209435971 sha256=7f735c8de48f7218378d781f273d78f4ab02a7b8adb785221fd9aa02d806d686
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/7f/28/02/0373b4f55c817bebc0dfe467728642269180aecfc771cebd06
# Successfully built pyspark
# WARNING: Error parsing requirements for py4j: [Errno 2] No such file or directory: '/home/ubuntu/.local/lib/python3.8/site-packages/py4j-0.10.9.9.dist-info/METADATA'
# Installing collected packages: py4j, pyspark
#   Attempting uninstall: py4j
#     Found existing installation: py4j 0.10.9.9
#     Can't uninstall 'py4j'. No files were found to uninstall.
# Successfully installed py4j-0.10.9 pyspark-3.0.3

# %%
from pyspark.sql import SparkSession

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("ReadData").getOrCreate()
df_text = spark.read.text("hdfs:///user/ubuntu/data/*.txt")

# %%
 
from pyspark.sql import functions as F

# Количество записей
print(f"Всего строк: {df_text.count()}")

# Посмотреть 10 строк
df_text.show(10, truncate=False)

# Посмотреть схему
df_text.printSchema()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8af5018dd861> in <module>
#       2
#       3 # Количество записей
# ----> 4 print(f"Всего строк: {df_text.count()}")
#       5
#       6 # Посмотреть 10 строк
#
# ~/.local/lib/python3.8/site-packages/pyspark/sql/dataframe.py in count(self)
#     583         2
#     584         """
# --> 585         return int(self._jdf.count())
#     586
#     587     @ignore_unicode_prefix
#
# ~/.local/lib/python3.8/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1301             proto.END_COMMAND_PART
#    1302
# -> 1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# ~/.local/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1031         connection = self._get_connection()
#    1032         try:
# -> 1033             response = connection.send_command(command)
#    1034             if binary:
#    1035                 return response, self._create_connection_guard(connection)
#
# ~/.local/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command)
#    1198
#    1199         try:
# -> 1200             answer = smart_decode(self.stream.readline()[:-1])
#    1201             logger.debug("Answer received: {0}".format(answer))
#    1202             if answer.startswith(proto.RETURN_MESSAGE):
#
# /opt/conda/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
